# %% [markdown]
# ## Clase 2 - Fundamentos Python
#
# ## Variables y tipos de datos

# %%
# ---Variables de entrada

nombre = "Alex Muñoz"
edad = 45
correo = "alexmunoz@gmail.com"
activo = True
promedio = 8.7

# ---Imprimir la información
print(f"Estudiante:{nombre}")
print(f"Edad:{edad} -> tipo {type(edad)}")
print(f"Correo:{correo}")
print(f"Activo:{activo}")
print(f"Promedio:{promedio}")
# Out:
# Estudiante:Alex Muñoz
# Edad:45 -> tipo <class 'int'>
# Correo:alexmunoz@gmail.com
# Activo:True
# Promedio:8.7

# %%
nombre = input("Ingresa nombre del estudiante: ")
edad = int(input("Ingresa edad: "))
print(f"Registrado {nombre} con una edad de: {edad}")
# Out:
# Registrado Alex con una edad de: 42

# %% [markdown]
# str -> string cadena de caracteres
# int -> Enteros
# float -> Float punto flotante, números con decimales
# bool -> Booleano T/F

# %% [markdown]
# ## ✅ Listas y diccionarios
#
# > Listas:
# Colección ordenada, implementada como un array dinámico, su acceso lo tiene por índices.

# %%
# Lista de estudiantes

estudiantes = ["Graciela", "Andrés", "Carolina"]

print(estudiantes[1])
print(estudiantes[-1])
print(len(estudiantes))
estudiantes.append("Alex")
print(estudiantes)
#estudiantes.pop(1)
# Out:
# Andrés
# Carolina
# 3
# ['Graciela', 'Andrés', 'Carolina', 'Alex']

# %% [markdown]
# # Diccionarios:
#
# Pares de clave - valor

# %%
import json
# Registro de estudiantes:

estudiante = {
    "nombre" : "Alex Munoz",
    "edad" : 45,
    "correo" : "alexmunoz@gmail.com",
    "activo" : True,
    "promedio" : 8.7
}

# print(estudiante)
# print(f"estudiante: {estudiante['nombre']}")
# print(f"Edad: {estudiante['edad']}")
# print(f"Correo: {estudiante['correo']}")
# print(f"E-mail: {estudiante['correo']}")
# print(f"Activo: {estudiante['activo']}")

# # Actualizo un valor del diccionario
# estudiante["activo"] = False
# print(estudiante)

# Ahora agregando varios estudiantes

alumnos = [
    estudiante,  #Aqui añado el estudiante de arriba para no escribirlo de nuevo
    {
        "nombre" : "Carlos Munoz",
        "edad" : 45,
        "correo" : "alexmunoz@gmail.com",
        "activo" : True,
        "promedio" : 8.7

    },
    {
        "nombre" : "Martha Munoz",
        "edad" : 45,
        "correo" : "alexmunoz@gmail.com",
        "activo" : True,
        "promedio" : 8.7

    },
]

print("estudiantes: ")
print(json.dumps(alumnos, indent=4))
print(alumnos[0]["correo"])
# Out:
# estudiantes:
# [
#     {
#         "nombre": "Alex Munoz",
#         "edad": 45,
#         "correo": "alexmunoz@gmail.com",
#         "activo": true,
#         "promedio": 8.7
#     },
#     {
#         "nombre": "Carlos Munoz",
#         "edad": 45,
#         "correo": "alexmunoz@gmail.com",
#         "activo": true,
#         "promedio": 8.7
#     },
#     {
#         "nombre": "Martha Munoz",
#         "edad": 45,
#         "correo": "alexmunoz@gmail.com",
#         "activo": true,
#         "promedio": 8.7
#     }
# ]
# alexmunoz@gmail.com

# %% [markdown]
# # Condicionales y blucles
#
# > Condicionales -> if/elif/else, es una estructura de control, controla el flujo del programa

# %%
nombre = "Alex"
promedio = 7

if promedio >= 7:
    print(f"Felicitaciones {nombre}")
elif promedio >= 5:
    print(f"Puedes mejorar")
else:
    print(f"Necesitas mejorar")
# Out:
# Felicitaciones Alex

# %% [markdown]
# ## Bucles
#
# > For, es una estructura de iteración, recorre todo el elemento

# %%
learners = [
    {"nombre": "Alex", "promedio": 8.7},
    {"nombre": "Carlos", "promedio": 7.5},
    {"nombre": "Maria", "promedio": 5}
] 

for learner in learners:
    if learner["promedio"] >= 7:
        print(f"Felicitaciones {learner['nombre']}")
    elif learner["promedio"] >= 5:
        print(f"Puedes mejorar")
    else:
        print(f"Necesitas mejorar")
# Out:
# Felicitaciones Alex
# Felicitaciones Carlos
# Puedes mejorar

# %% [markdown]
# ## Funciones
